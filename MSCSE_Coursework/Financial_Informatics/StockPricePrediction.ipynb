# %% [markdown]
# ## Stock Return Prediction
#
# In this case study we will use various supervised learning-based models to predict the
# stock price of Microsoft using correlated assets and its own historical data.

# %% [markdown]
# ## Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Libraries and Dataset](#1)
#     * [2.1. Load Libraries](#1.1)
#     * [2.2. Load Dataset](#1.2)
# * [3. Exploratory Data Analysis](#2)
#     * [3.1 Descriptive Statistics](#2.1)
#     * [3.2. Data Visualisation](#2.2)
# * [4. Data Preparation](#3)
#     * [4.1 Data Cleaning](#3.1)
#     * [4.2.Feature Selection](#3.2)
# * [5.Evaluate Algorithms and Models](#4)
#     * [5.1. Train/Test Split](#4.1)
#     * [5.2. Evaluation Metrics](#4.2)
#     * [5.3. Compare Models and Algorithms](#4.3)
#         * [5.3.1 Machine Learning models-scikit-learn](#4.3.1)
#         * [5.3.2 Time Series based Models-ARIMA and LSTM](#4.3.2)
# * [6. Model Tuning and grid search](#5)
# * [7. Finalise the model](#6)
#     * [7.1. Result on the test dataset](#6.1)
#     * [7.2. Save Model for Later Use](#6.2)

# %% [markdown]
# <a id='0'></a>
# # 1. Problem Definition

# %% [markdown]
# In the supervised regression framework used for this case study, weekly return of the
# Microsoft stock is the predicted variable. We need to understand what affects Microsoft stock price and hence incorporate as much information into the model.
#
# For this case study, other than the historical data of Microsoft, the independent variables used are the following potentially correlated assets:
# * Stocks: IBM (IBM) and Alphabet (GOOGL)
# * Currency: USD/JPY and GBP/USD
# * Indices: S&P 500, Dow Jones and VIX

# %% [markdown]
# <a id='1'></a>
# # 2. Getting Started- Loading the data and python packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Loading the python packages

# %%
# !pip install pandas_datareader --upgrade
# Load libraries
import numpy as np
import pandas as pd
import pandas_datareader.data as web
from matplotlib import pyplot
from pandas.plotting import scatter_matrix
import seaborn as sns
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.neural_network import MLPRegressor

#Libraries for Deep Learning Models
from keras.models import Sequential
from keras.layers import Dense
#from keras.optimizers import SGD
from keras.layers import LSTM
from keras.wrappers.scikit_learn import KerasRegressor

#Libraries for Statistical Models
import statsmodels.api as sm

#Libraries for Saving the Model
from pickle import dump
from pickle import load

# Time series Models
from statsmodels.tsa.arima_model import ARIMA
#from statsmodels.tsa.statespace.sarimax import SARIMAX

# Error Metrics
from sklearn.metrics import mean_squared_error

# Feature Selection
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2, f_regression


#Plotting
from pandas.plotting import scatter_matrix
from statsmodels.graphics.tsaplots import plot_acf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas_datareader in /usr/local/lib/python3.10/dist-packages (0.10.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from pandas_datareader) (4.9.2)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.10/dist-packages (from pandas_datareader) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pandas_datareader) (2.27.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas_datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas_datareader) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas_datareader) (1.22.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas_datareader) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas_datareader) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas_datareader) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas_datareader) (3.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.23->pandas_datareader) (1.16.0)

# %%
#Diable the warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Loading the Data

# %% [markdown]
# Next, we extract the data required for our analysis using pandas datareader.

# %%
stk_tickers = ['MSFT', 'IBM', 'GOOGL']
ccy_tickers = ['DEXJPUS', 'DEXUSUK']
idx_tickers = ['SP500', 'DJIA', 'VIXCLS']

stk_data = web.DataReader(stk_tickers, 'yahoo')
ccy_data = web.DataReader(ccy_tickers, 'fred')
idx_data = web.DataReader(idx_tickers, 'fred')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-9088a04d9269> in <cell line: 5>()
#       3 idx_tickers = ['SP500', 'DJIA', 'VIXCLS']
#       4
# ----> 5 stk_data = web.DataReader(stk_tickers, 'yahoo')
#       6 ccy_data = web.DataReader(ccy_tickers, 'fred')
#       7 idx_data = web.DataReader(idx_tickers, 'fred')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     377             pause=pause,
#     378             session=session,
# --> 379         ).read()
#     380
#     381     elif data_source == "iex":
#
# /usr/local/lib/python3.10/dist-packages/pandas_datareader/base.py in read(self)
#     256             df = self._dl_mult_symbols(self.symbols.index)
#     257         else:
# --> 258             df = self._dl_mult_symbols(self.symbols)
#     259         return df
#     260
#
# /usr/local/lib/python3.10/dist-packages/pandas_datareader/base.py in _dl_mult_symbols(self, symbols)
#     266             for sym in sym_group:
#     267                 try:
# --> 268                     stocks[sym] = self._read_one_data(self.url, self._get_params(sym))
#     269                     passed.append(sym)
#     270                 except (IOError, KeyError):
#
# /usr/local/lib/python3.10/dist-packages/pandas_datareader/yahoo/daily.py in _read_one_data(self, url, params)
#     151         try:
#     152             j = json.loads(re.search(ptrn, resp.text, re.DOTALL).group(1))
# --> 153             data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
#     154         except KeyError:
#     155             msg = "No data fetched for symbol {} using {}"
#
# TypeError: string indices must be integers

# %% [markdown]
# Next, we need a series to predict. We choose to predict using weekly returns. We approximate this by using 5 business day period returns.

# %%
return_period = 5

# %% [markdown]
# We now define our Y series and our X series
#
# Y: MSFT **Future** Returns
#
# X:
#
#     a. GOOGL 5 Business Day Returns
#     b. IBM 5 Business DayReturns
#     c. USD/JPY 5 Business DayReturns
#     d. GBP/USD 5 Business DayReturns
#     e. S&P 500 5 Business DayReturns
#     f. Dow Jones 5 Business DayReturns
#     g. MSFT 5 Business Day Returns
#     h. MSFT 15 Business Day Returns
#     i. MSFT 30 Business Day Returns
#     j. MSFT 60 Business Day Returns
#
# We remove the MSFT past returns when we use the Time series models.

# %%
stk_data.head()
# Out:
# Attributes  Adj Close                          ...      Volume
# Symbols          MSFT         IBM       GOOGL  ...        MSFT        IBM      GOOGL
# Date                                           ...
# 2017-02-27  59.957729  135.802719  849.669983  ...  15871500.0  3861100.0  1010300.0
# 2017-02-28  59.724365  136.120651  844.929993  ...  23239800.0  3423976.0  1383100.0
# 2017-03-01  60.620502  137.733002  856.750000  ...  26937500.0  3143858.0  1818700.0
# 2017-03-02  59.752361  136.658127  849.849976  ...  24539600.0  3052437.0  1250900.0
# 2017-03-03  59.976398  136.294769  849.080017  ...  18135900.0  1905812.0  1005000.0
#
# [5 rows x 18 columns]

# %%
temp_data=stk_data[('Adj Close','MSFT')]

# %%
temp_data
# Out:
# Date
# 2016-03-14     48.755386
# 2016-03-15     49.140518
# 2016-03-16     49.837418
# 2016-03-17     50.121674
# 2016-03-18     49.048813
#                  ...
# 2021-03-05    231.600006
# 2021-03-08    227.389999
# 2021-03-09    233.779999
# 2021-03-10    232.419998
# 2021-03-11    237.130005
# Name: (Adj Close, MSFT), Length: 1258, dtype: float64

# %%
temp_data.diff(5)
# Out:
# Date
# 2016-03-14          NaN
# 2016-03-15          NaN
# 2016-03-16          NaN
# 2016-03-17          NaN
# 2016-03-18          NaN
#                 ...
# 2021-03-05    -0.779999
# 2021-03-08    -9.550003
# 2021-03-09    -0.089996
# 2021-03-10     4.860001
# 2021-03-11    10.400009
# Name: (Adj Close, MSFT), Length: 1258, dtype: float64

# %%
Y = np.log(stk_data.loc[:, ('Adj Close', 'MSFT')]).diff(return_period).shift(-return_period)
Y.name = Y.name[-1]+'_pred'

X1 = np.log(stk_data.loc[:, ('Adj Close', ('GOOGL', 'IBM'))]).diff(return_period)
X1.columns = X1.columns.droplevel()
X2 = np.log(ccy_data).diff(return_period)
X3 = np.log(idx_data).diff(return_period)

X4 = pd.concat([np.log(stk_data.loc[:, ('Adj Close', 'MSFT')]).diff(i) for i in [return_period, return_period*3, return_period*6, return_period*12]], axis=1).dropna()
X4.columns = ['MSFT_DT', 'MSFT_3DT', 'MSFT_6DT', 'MSFT_12DT']

X = pd.concat([X1, X2, X3, X4], axis=1)

dataset = pd.concat([Y, X], axis=1).dropna().iloc[::return_period, :]
Y = dataset.loc[:, Y.name]
X = dataset.loc[:, X.columns]

# %% [markdown]
# <a id='2'></a>
# # 3. Exploratory Data Analysis

# %% [markdown]
# <a id='2.1'></a>
# ## 3.1. Descriptive Statistics

# %% [markdown]
# Lets have a look at the dataset we have

# %%
pd.set_option('precision', 3)
dataset.describe()
# Out:
#        MSFT_pred        IBM    GOOGL  ...  MSFT_3DT  MSFT_6DT  MSFT_12DT
# count    225.000  2.250e+02  225.000  ...   225.000   225.000    225.000
# mean       0.007  1.605e-04    0.005  ...     0.020     0.041      0.078
# std        0.028  3.369e-02    0.034  ...     0.045     0.055      0.068
# min       -0.120 -1.569e-01   -0.131  ...    -0.149    -0.238     -0.116
# 25%       -0.007 -1.462e-02   -0.012  ...    -0.004     0.012      0.039
# 50%        0.008  1.430e-03    0.008  ...     0.023     0.044      0.077
# 75%        0.022  1.777e-02    0.026  ...     0.042     0.072      0.124
# max        0.077  9.203e-02    0.089  ...     0.147     0.244      0.306
#
# [8 rows x 12 columns]

# %%
dataset.head()
# Out:
#             MSFT_pred    IBM  GOOGL  ...  MSFT_3DT   MSFT_6DT  MSFT_12DT
# 2016-06-08     -0.046  0.010 -0.007  ...     0.030  1.857e-02     -0.015
# 2016-06-15      0.026 -0.022 -0.015  ...    -0.038  5.160e-03     -0.074
# 2016-06-22     -0.009  0.015 -0.030  ...    -0.036  6.382e-03     -0.063
# 2016-06-29      0.016 -0.030 -0.022  ...    -0.029  5.938e-04     -0.070
# 2016-07-07      0.045  0.028  0.017  ...     0.033 -4.079e-03     -0.055
#
# [5 rows x 12 columns]

# %% [markdown]
# <a id='2.2'></a>
# ## 3.2. Data Visualization

# %% [markdown]
# Next, lets look at the distribution of the data over the entire period

# %%
dataset.hist(bins=50, sharex=False, sharey=False, xlabelsize=1, ylabelsize=1, figsize=(12,12))
pyplot.show()

# %% [markdown]
# The above histogram shows the distribution for each series individually. Next, lets look at the density distribution over the same x axis scale.

# %%
dataset.plot(kind='density', subplots=True, layout=(4,4), sharex=True, legend=True, fontsize=1, figsize=(15,15))
pyplot.show()

# %% [markdown]
# We can see that the vix has a much larger variance compared to the other distributions.

# %% [markdown]
# In order to get a sense of the interdependence of the data we look at the scatter plot and the correlation matrix

# %%
correlation = dataset.corr()
pyplot.figure(figsize=(15,15))
pyplot.title('Correlation Matrix')
sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='cubehelix')

# %% [markdown]
# Looking at the correlation plot above, we see some correlation of the predicted vari‐
# able with the lagged 5 days, 15days, 30 days and 60 days return of MSFT.

# %%
pyplot.figure(figsize=(15,15))
scatter_matrix(dataset,figsize=(12,12))
pyplot.show()

# %% [markdown]
# Looking at the scatter plot above, we see some linear relationship of the predicted
# variable the lagged 15 days, 30 days and 60 days return of MSFT.

# %% [markdown]
# <a id='2.3'></a>
# ## 3.3. Time Series Analysis

# %% [markdown]
# Next, we look at the seasonal decomposition of our time series

# %%
res = sm.tsa.seasonal_decompose(Y,freq=52)
fig = res.plot()
fig.set_figheight(8)
fig.set_figwidth(15)
pyplot.show()

# %% [markdown]
# We can see that for MSFT there has been a general trend upwards. This should show up in our the constant/bias terms in our models

# %% [markdown]
# <a id='3'></a>
# ## 4. Data Preparation

# %% [markdown]
# <a id='3.2'></a>
# ## 4.2. Feature Selection

# %% [markdown]
# We use sklearn's SelectKBest function to get a sense of feature importance.

# %%
bestfeatures = SelectKBest(k=5, score_func=f_regression)
fit = bestfeatures.fit(X,Y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
#concat two dataframes for better visualization
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
featureScores.nlargest(10,'Score').set_index('Specs')  #print 10 best features
# Out:
#            Score
# Specs
# MSFT_6DT   9.112
# MSFT_12DT  2.601
# MSFT_3DT   2.196
# DEXJPUS    1.121
# VIXCLS     0.736
# MSFT_DT    0.722
# IBM        0.404
# DEXUSUK    0.235
# GOOGL      0.217
# SP500      0.047

# %% [markdown]
# We see that IBM seems to be the most important feature and vix being the least important.

# %% [markdown]
# <a id='4'></a>
# # 5. Evaluate Algorithms and Models

# %% [markdown]
# <a id='4.1'></a>
# ## 5.1. Train Test Split and Evaluation Metrics

# %% [markdown]
# Next, we start by splitting our data in training and testing chunks. If we are going to use Time series models we have to split the data in continous series.

# %%
validation_size = 0.2

#In case the data is not dependent on the time series, then train and test split randomly
# seed = 7
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=validation_size, random_state=seed)

#In case the data is not dependent on the time series, then train and test split should be done based on sequential sample
#This can be done by selecting an arbitrary split point in the ordered list of observations and creating two new datasets.
train_size = int(len(X) * (1-validation_size))
X_train, X_test = X[0:train_size], X[train_size:len(X)]
Y_train, Y_test = Y[0:train_size], Y[train_size:len(X)]

# %% [markdown]
# <a id='4.2'></a>
# ## 5.2. Test Options and Evaluation Metrics

# %%
num_folds = 10
seed = 7
# scikit is moving away from mean_squared_error.
# In order to avoid confusion, and to allow comparison with other models, we invert the final scores
scoring = 'neg_mean_squared_error'

# %% [markdown]
# <a id='4.3'></a>
# ## 5.3. Compare Models and Algorithms

# %% [markdown]
# <a id='4.3.1'></a>
# ### 5.3.1 Machine Learning models-from scikit-learn

# %% [markdown]
# ##### Regression and Tree Regression algorithms

# %%
models = []
models.append(('LR', LinearRegression()))
models.append(('LASSO', Lasso()))
models.append(('EN', ElasticNet()))
models.append(('KNN', KNeighborsRegressor()))
models.append(('CART', DecisionTreeRegressor()))
models.append(('SVR', SVR()))

# %% [markdown]
# ##### Neural Network algorithms

# %%
models.append(('MLP', MLPRegressor()))

# %% [markdown]
# ##### Ensemble Models

# %%
# Boosting methods
models.append(('ABR', AdaBoostRegressor()))
models.append(('GBR', GradientBoostingRegressor()))
# Bagging methods
models.append(('RFR', RandomForestRegressor()))
models.append(('ETR', ExtraTreesRegressor()))

# %% [markdown]
# Once we have selected all the models, we loop over each of them. First we run the K-fold analysis. Next we run the model on the entire training and testing dataset.

# %%
names = []
kfold_results = []
test_results = []
train_results = []
for name, model in models:
    names.append(name)

    ## K Fold analysis:

    kfold = KFold(n_splits=num_folds, random_state=seed)
    #converted mean square error to positive. The lower the beter
    cv_results = -1* cross_val_score(model, X_train, Y_train, cv=kfold, scoring=scoring)
    kfold_results.append(cv_results)


    # Full Training period
    res = model.fit(X_train, Y_train)
    train_result = mean_squared_error(res.predict(X_train), Y_train)
    train_results.append(train_result)

    # Test results
    test_result = mean_squared_error(res.predict(X_test), Y_test)
    test_results.append(test_result)

    msg = "%s: %f (%f) %f %f" % (name, cv_results.mean(), cv_results.std(), train_result, test_result)
    print(msg)
# Out:
# LR: 0.000761 (0.000654) 0.000609 0.001610
# LASSO: 0.000660 (0.000482) 0.000651 0.001538
# EN: 0.000660 (0.000482) 0.000651 0.001538
# KNN: 0.000777 (0.000508) 0.000523 0.001655
# CART: 0.001268 (0.000881) 0.000000 0.003550
# SVR: 0.001015 (0.000388) 0.001023 0.002018
# MLP: 0.001626 (0.001352) 0.000864 0.001697
# ABR: 0.000682 (0.000496) 0.000317 0.001701
# GBR: 0.000883 (0.000673) 0.000046 0.002323
# RFR: 0.000802 (0.000631) 0.000106 0.001944
# ETR: 0.000751 (0.000547) 0.000000 0.001793

# %% [markdown]
# #### K Fold results

# %% [markdown]
# We being by looking at the K Fold results

# %%
fig = pyplot.figure()
fig.suptitle('Algorithm Comparison: Kfold results')
ax = fig.add_subplot(111)
pyplot.boxplot(kfold_results)
ax.set_xticklabels(names)
fig.set_size_inches(15,8)
pyplot.show()

# %% [markdown]
# We see the linear regression and the regularized regression including the Lasso regression (LASSO) and elastic net (EN) seem to do a good job.

# %% [markdown]
# #### Training and Test error

# %%
# compare algorithms
fig = pyplot.figure()

ind = np.arange(len(names))  # the x locations for the groups
width = 0.35  # the width of the bars

fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
pyplot.bar(ind - width/2, train_results,  width=width, label='Train Error')
pyplot.bar(ind + width/2, test_results, width=width, label='Test Error')
fig.set_size_inches(15,8)
pyplot.legend()
ax.set_xticks(ind)
ax.set_xticklabels(names)
pyplot.show()

# %% [markdown]
# Looking at the training and test error, we still see a better performance of the linear models. Some of the algorithms, such as the decision tree regressor (CART) overfit on
# the training data and produced very high error on the test set and these models
# should be avoided. Ensemble models, such as gradient boosting regression (GBR) and
# random forest regression (RFR) have low bias but high variance. We also see that the
# artificial neural network (shown as MLP is the chart) algorithm shows higher errors
# both in training set and test set, which is perhaps due to the linear relationship of the
# variables not captured accurately by ANN or improper hyperparameters or insuffi‐
# cient training of the model.

# %% [markdown]
# <a id='4.3.1'></a>
# ### 5.3.1 Time Series based models-ARIMA and LSTM

# %% [markdown]
# Let us first prepare the dataset for ARIMA models,
# by having only the correlated varriables as exogenous variables.

# %% [markdown]
# ### Time Series Model - ARIMA Model

# %%
X_train_ARIMA=X_train.loc[:, ['GOOGL', 'IBM', 'DEXJPUS', 'SP500', 'DJIA', 'VIXCLS']]
X_test_ARIMA=X_test.loc[:, ['GOOGL', 'IBM', 'DEXJPUS', 'SP500', 'DJIA', 'VIXCLS']]
tr_len = len(X_train_ARIMA)
te_len = len(X_test_ARIMA)
to_len = len (X)

# %%
modelARIMA=ARIMA(endog=Y_train,exog=X_train_ARIMA,order=[1,0,0])
model_fit = modelARIMA.fit()

# %%
error_Training_ARIMA = mean_squared_error(Y_train, model_fit.fittedvalues)
predicted = model_fit.predict(start = tr_len -1 ,end = to_len -1, exog = X_test_ARIMA)[1:]
error_Test_ARIMA = mean_squared_error(Y_test,predicted)
error_Test_ARIMA
# Out:
# 0.0016485986561582166

# %% [markdown]
# ###  LSTM Model

# %%
seq_len = 2 #Length of the seq for the LSTM

Y_train_LSTM, Y_test_LSTM = np.array(Y_train)[seq_len-1:], np.array(Y_test)
X_train_LSTM = np.zeros((X_train.shape[0]+1-seq_len, seq_len, X_train.shape[1]))
X_test_LSTM = np.zeros((X_test.shape[0], seq_len, X.shape[1]))
for i in range(seq_len):
    X_train_LSTM[:, i, :] = np.array(X_train)[i:X_train.shape[0]+i+1-seq_len, :]
    X_test_LSTM[:, i, :] = np.array(X)[X_train.shape[0]+i-1:X.shape[0]+i+1-seq_len, :]

# %%
# Lstm Network
def create_LSTMmodel(neurons=12, learn_rate = 0.01, momentum=0):
        # create model
    model = Sequential()
    model.add(LSTM(50, input_shape=(X_train_LSTM.shape[1], X_train_LSTM.shape[2])))
    #More number of cells can be added if needed
    model.add(Dense(1))
    optimizer = SGD(lr=learn_rate, momentum=momentum)
    model.compile(loss='mse', optimizer='adam')
    return model
LSTMModel = create_LSTMmodel(12, learn_rate = 0.01, momentum=0)
LSTMModel_fit = LSTMModel.fit(X_train_LSTM, Y_train_LSTM, validation_data=(X_test_LSTM, Y_test_LSTM),epochs=330, batch_size=72, verbose=1, shuffle=False)
# Out:
# Epoch 1/330
# 3/3 [==============================] - 2s 250ms/step - loss: 6.8060e-04 - val_loss: 0.0014
# Epoch 2/330
# 3/3 [==============================] - 0s 26ms/step - loss: 5.5589e-04 - val_loss: 0.0015
# Epoch 3/330
# 3/3 [==============================] - 0s 25ms/step - loss: 5.8198e-04 - val_loss: 0.0014
# Epoch 4/330
# 3/3 [==============================] - 0s 25ms/step - loss: 5.4340e-04 - val_loss: 0.0015
# Epoch 5/330
# 3/3 [==============================] - 0s 26ms/step - loss: 5.5345e-04 - val_loss: 0.0015
# Epoch 6/330
# 3/3 [==============================] - 0s 25ms/step - loss: 5.5664e-04 - val_loss: 0.0015
# Epoch 7/330
# 3/3 [==============================] - 0s 25ms/step - loss: 5.3905e-04 - val_loss: 0.0014
# Epoch 8/330
# 3/3 [==============================] - 0s 27ms/step - loss: 5.3959e-04 - val_loss: 0.0014
# Epoch 9/330
# 3/3 [==============================] - 0s 25ms/step - loss: 5.4127e-04 - val_loss: 0.0014
# Epoch 10/330
# 3/3 [==============================] - 0s 28ms/step - loss: 5.3606e-04 - val_loss: 0.0015
# Epoch 11/330
# 3/3 [==============================] - 0s 27ms/step - loss: 5.3746e-04 - val_loss: 0.0015
# Epoch 12/330
# 3/3 [==============================] - 0s 29ms/step - loss: 5.3714e-04 - val_loss: 0.0015
# Epoch 13/330
# 3/3 [==============================] - 0s 32ms/step - loss: 5.3318e-04 - val_loss: 0.0015
# Epoch 14/330
# 3/3 [==============================] - 0s 30ms/step - loss: 5.3279e-04 - val_loss: 0.0015
# Epoch 15/330
# 3/3 [==============================] - 0s 29ms/step - loss: 5.3239e-04 - val_loss: 0.0015
# Epoch 16/330
# 3/3 [==============================] - 0s 29ms/step - loss: 5.3151e-04 - val_loss: 0.0015
# Epoch 17/330
# 3/3 [==============================] - 0s 28ms/step - loss: 5.3157e-04 - val_loss: 0.0015
# Epoch 18/330
# 3/3 [==============================] - 0s 25ms/step - loss: 5.3039e-04 - val_loss: 0.0015
# Epoch 19/330
# 3/3 [==============================] - 0s 26ms/step - loss: 5.2931e-04 - val_loss: 0.0015
# Epoch 20/330
# 3/3 [==============================] - 0s 24ms/step - loss: 5.2894e-04 - val_loss: 0.0015
# Epoch 21/330
# 3/3 [==============================] - 0s 26ms/step - loss: 5.2843e-04 - val_loss: 0.0015
# Epoch 22/330
# 3/3 [==============================] - 0s 25ms/step - loss: 5.2804e-04 - val_loss: 0.0015
# Epoch 23/330
# 3/3 [==============================] - 0s 29ms/step - loss: 5.2732e-04 - val_loss: 0.0015
# Epoch 24/330
# 3/3 [==============================] - 0s 26ms/step - loss: 5.2650e-04 - val_loss: 0.0015
# Epoch 25/330
# 3/3 [==============================] - 0s 26ms/step - loss: 5.2597e-04 - val_loss: 0.0015
# Epoch 26/330
# 3/3 [==============================] - 0s 25ms/step - loss: 5.2549e-04 - val_loss: 0.0015
# Epoch 27/330
# 3/3 [==============================] - 0s 25ms/step - loss: 5.2500e-04 - val_loss: 0.0015
# Epoch 28/330
# 3/3 [==============================] - 0s 25ms/step - loss: 5.2440e-04 - val_loss: 0.0015
# Epoch 29/330
# 3/3 [==============================] - 0s 28ms/step - loss: 5.2378e-04 - val_loss: 0.0015
# Epoch 30/330
# 3/3 [==============================] - 0s 25ms/step - loss: 5.2331e-04 - val_loss: 0.0015
# Epoch 31/330
# 3/3 [==============================] - 0s 26ms/step - loss: 5.2288e-04 - val_loss: 0.0015
# Epoch 32/330
# 3/3 [==============================] - 0s 27ms/step - loss: 5.2243e-04 - val_loss: 0.0015
# Epoch 33/330
# 3/3 [==============================] - 0s 27ms/step - loss: 5.2194e-04 - val_loss: 0.0015
# Epoch 34/330
# 3/3 [==============================] - 0s 27ms/step - loss: 5.2147e-04 - val_loss: 0.0015
# Epoch 35/330
# 3/3 [==============================] - 0s 30ms/step - loss: 5.2108e-04 - val_loss: 0.0015
# Epoch 36/330
# 3/3 [==============================] - 0s 31ms/step - loss: 5.2069e-04 - val_loss: 0.0015
# Epoch 37/330
# 3/3 [==============================] - 0s 28ms/step - loss: 5.2029e-04 - val_loss: 0.0015
# Epoch 38/330
# 3/3 [==============================] - 0s 29ms/step - loss: 5.1988e-04 - val_loss: 0.0015
# Epoch 39/330
# 3/3 [==============================] - 0s 27ms/step - loss: 5.1951e-04 - val_loss: 0.0015
# Epoch 40/330
# 3/3 [==============================] - 0s 24ms/step - loss: 5.1916e-04 - val_loss: 0.0015
# Epoch 41/330
# 3/3 [==============================] - 0s 26ms/step - loss: 5.1881e-04 - val_loss: 0.0015
# Epoch 42/330
# 3/3 [==============================] - 0s 25ms/step - loss: 5.1846e-04 - val_loss: 0.0015
# Epoch 43/330
# 3/3 [==============================] - 0s 33ms/step - loss: 5.1812e-04 - val_loss: 0.0015
# Epoch 44/330
# 3/3 [==============================] - 0s 35ms/step - loss: 5.1780e-04 - val_loss: 0.0015
# Epoch 45/330
# 3/3 [==============================] - 0s 31ms/step - loss: 5.1749e-04 - val_loss: 0.0015
# Epoch 46/330
# 3/3 [==============================] - 0s 32ms/step - loss: 5.1717e-04 - val_loss: 0.0016
# Epoch 47/330
# 3/3 [==============================] - 0s 31ms/step - loss: 5.1686e-04 - val_loss: 0.0016
# Epoch 48/330
# 3/3 [==============================] - 0s 36ms/step - loss: 5.1656e-04 - val_loss: 0.0016
# Epoch 49/330
# 3/3 [==============================] - 0s 34ms/step - loss: 5.1627e-04 - val_loss: 0.0016
# Epoch 50/330
# 3/3 [==============================] - 0s 32ms/step - loss: 5.1598e-04 - val_loss: 0.0016
# Epoch 51/330
# 3/3 [==============================] - 0s 32ms/step - loss: 5.1568e-04 - val_loss: 0.0016
# Epoch 52/330
# 3/3 [==============================] - 0s 33ms/step - loss: 5.1539e-04 - val_loss: 0.0016
# Epoch 53/330
# 3/3 [==============================] - 0s 35ms/step - loss: 5.1511e-04 - val_loss: 0.0016
# Epoch 54/330
# 3/3 [==============================] - 0s 32ms/step - loss: 5.1483e-04 - val_loss: 0.0016
# Epoch 55/330
# 3/3 [==============================] - 0s 32ms/step - loss: 5.1454e-04 - val_loss: 0.0016
# Epoch 56/330
# 3/3 [==============================] - 0s 29ms/step - loss: 5.1426e-04 - val_loss: 0.0016
# Epoch 57/330
# 3/3 [==============================] - 0s 26ms/step - loss: 5.1398e-04 - val_loss: 0.0016
# Epoch 58/330
# 3/3 [==============================] - 0s 29ms/step - loss: 5.1370e-04 - val_loss: 0.0016
# Epoch 59/330
# 3/3 [==============================] - 0s 27ms/step - loss: 5.1342e-04 - val_loss: 0.0016
# Epoch 60/330
# 3/3 [==============================] - 0s 27ms/step - loss: 5.1313e-04 - val_loss: 0.0016
# Epoch 61/330
# 3/3 [==============================] - 0s 26ms/step - loss: 5.1285e-04 - val_loss: 0.0016
# Epoch 62/330
# 3/3 [==============================] - 0s 27ms/step - loss: 5.1257e-04 - val_loss: 0.0016
# Epoch 63/330
# 3/3 [==============================] - 0s 26ms/step - loss: 5.1228e-04 - val_loss: 0.0016
# Epoch 64/330
# 3/3 [==============================] - 0s 24ms/step - loss: 5.1199e-04 - val_loss: 0.0016
# Epoch 65/330
# 3/3 [==============================] - 0s 24ms/step - loss: 5.1170e-04 - val_loss: 0.0016
# Epoch 66/330
# 3/3 [==============================] - 0s 27ms/step - loss: 5.1141e-04 - val_loss: 0.0016
# Epoch 67/330
# 3/3 [==============================] - 0s 26ms/step - loss: 5.1112e-04 - val_loss: 0.0016
# Epoch 68/330
# 3/3 [==============================] - 0s 25ms/step - loss: 5.1082e-04 - val_loss: 0.0016
# Epoch 69/330
# 3/3 [==============================] - 0s 26ms/step - loss: 5.1053e-04 - val_loss: 0.0016
# Epoch 70/330
# 3/3 [==============================] - 0s 26ms/step - loss: 5.1023e-04 - val_loss: 0.0016
# Epoch 71/330
# 3/3 [==============================] - 0s 27ms/step - loss: 5.0992e-04 - val_loss: 0.0016
# Epoch 72/330
# 3/3 [==============================] - 0s 28ms/step - loss: 5.0961e-04 - val_loss: 0.0016
# Epoch 73/330
# 3/3 [==============================] - 0s 27ms/step - loss: 5.0930e-04 - val_loss: 0.0016
# Epoch 74/330
# 3/3 [==============================] - 0s 31ms/step - loss: 5.0899e-04 - val_loss: 0.0016
# Epoch 75/330
# 3/3 [==============================] - 0s 28ms/step - loss: 5.0867e-04 - val_loss: 0.0016
# Epoch 76/330
# 3/3 [==============================] - 0s 30ms/step - loss: 5.0835e-04 - val_loss: 0.0016
# Epoch 77/330
# 3/3 [==============================] - 0s 26ms/step - loss: 5.0803e-04 - val_loss: 0.0016
# Epoch 78/330
# 3/3 [==============================] - 0s 28ms/step - loss: 5.0770e-04 - val_loss: 0.0016
# Epoch 79/330
# 3/3 [==============================] - 0s 27ms/step - loss: 5.0737e-04 - val_loss: 0.0016
# Epoch 80/330
# 3/3 [==============================] - 0s 30ms/step - loss: 5.0704e-04 - val_loss: 0.0016
# Epoch 81/330
# 3/3 [==============================] - 0s 29ms/step - loss: 5.0670e-04 - val_loss: 0.0017
# Epoch 82/330
# 3/3 [==============================] - 0s 28ms/step - loss: 5.0635e-04 - val_loss: 0.0017
# Epoch 83/330
# 3/3 [==============================] - 0s 29ms/step - loss: 5.0600e-04 - val_loss: 0.0017
# Epoch 84/330
# 3/3 [==============================] - 0s 25ms/step - loss: 5.0565e-04 - val_loss: 0.0017
# Epoch 85/330
# 3/3 [==============================] - 0s 27ms/step - loss: 5.0530e-04 - val_loss: 0.0017
# Epoch 86/330
# 3/3 [==============================] - 0s 28ms/step - loss: 5.0493e-04 - val_loss: 0.0017
# Epoch 87/330
# 3/3 [==============================] - 0s 33ms/step - loss: 5.0457e-04 - val_loss: 0.0017
# Epoch 88/330
# 3/3 [==============================] - 0s 37ms/step - loss: 5.0420e-04 - val_loss: 0.0017
# Epoch 89/330
# 3/3 [==============================] - 0s 36ms/step - loss: 5.0382e-04 - val_loss: 0.0017
# Epoch 90/330
# 3/3 [==============================] - 0s 33ms/step - loss: 5.0344e-04 - val_loss: 0.0017
# Epoch 91/330
# 3/3 [==============================] - 0s 35ms/step - loss: 5.0306e-04 - val_loss: 0.0017
# Epoch 92/330
# 3/3 [==============================] - 0s 36ms/step - loss: 5.0267e-04 - val_loss: 0.0017
# Epoch 93/330
# 3/3 [==============================] - 0s 35ms/step - loss: 5.0228e-04 - val_loss: 0.0017
# Epoch 94/330
# 3/3 [==============================] - 0s 32ms/step - loss: 5.0188e-04 - val_loss: 0.0017
# Epoch 95/330
# 3/3 [==============================] - 0s 32ms/step - loss: 5.0148e-04 - val_loss: 0.0017
# Epoch 96/330
# 3/3 [==============================] - 0s 32ms/step - loss: 5.0107e-04 - val_loss: 0.0017
# Epoch 97/330
# 3/3 [==============================] - 0s 33ms/step - loss: 5.0065e-04 - val_loss: 0.0017
# Epoch 98/330
# 3/3 [==============================] - 0s 33ms/step - loss: 5.0023e-04 - val_loss: 0.0017
# Epoch 99/330
# 3/3 [==============================] - 0s 32ms/step - loss: 4.9981e-04 - val_loss: 0.0017
# Epoch 100/330
# 3/3 [==============================] - 0s 35ms/step - loss: 4.9938e-04 - val_loss: 0.0017
# Epoch 101/330
# 3/3 [==============================] - 0s 35ms/step - loss: 4.9895e-04 - val_loss: 0.0017
# Epoch 102/330
# 3/3 [==============================] - 0s 37ms/step - loss: 4.9851e-04 - val_loss: 0.0017
# Epoch 103/330
# 3/3 [==============================] - 0s 32ms/step - loss: 4.9807e-04 - val_loss: 0.0017
# Epoch 104/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.9762e-04 - val_loss: 0.0017
# Epoch 105/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.9716e-04 - val_loss: 0.0017
# Epoch 106/330
# 3/3 [==============================] - 0s 35ms/step - loss: 4.9670e-04 - val_loss: 0.0017
# Epoch 107/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.9624e-04 - val_loss: 0.0018
# Epoch 108/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.9577e-04 - val_loss: 0.0018
# Epoch 109/330
# 3/3 [==============================] - 0s 32ms/step - loss: 4.9530e-04 - val_loss: 0.0018
# Epoch 110/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.9482e-04 - val_loss: 0.0018
# Epoch 111/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.9433e-04 - val_loss: 0.0018
# Epoch 112/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.9385e-04 - val_loss: 0.0018
# Epoch 113/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.9335e-04 - val_loss: 0.0018
# Epoch 114/330
# 3/3 [==============================] - 0s 29ms/step - loss: 4.9286e-04 - val_loss: 0.0018
# Epoch 115/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.9236e-04 - val_loss: 0.0018
# Epoch 116/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.9185e-04 - val_loss: 0.0018
# Epoch 117/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.9134e-04 - val_loss: 0.0018
# Epoch 118/330
# 3/3 [==============================] - 0s 32ms/step - loss: 4.9083e-04 - val_loss: 0.0018
# Epoch 119/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.9032e-04 - val_loss: 0.0018
# Epoch 120/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.8980e-04 - val_loss: 0.0018
# Epoch 121/330
# 3/3 [==============================] - 0s 26ms/step - loss: 4.8928e-04 - val_loss: 0.0018
# Epoch 122/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.8875e-04 - val_loss: 0.0018
# Epoch 123/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.8823e-04 - val_loss: 0.0018
# Epoch 124/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.8770e-04 - val_loss: 0.0018
# Epoch 125/330
# 3/3 [==============================] - 0s 25ms/step - loss: 4.8717e-04 - val_loss: 0.0019
# Epoch 126/330
# 3/3 [==============================] - 0s 26ms/step - loss: 4.8664e-04 - val_loss: 0.0019
# Epoch 127/330
# 3/3 [==============================] - 0s 29ms/step - loss: 4.8611e-04 - val_loss: 0.0019
# Epoch 128/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.8558e-04 - val_loss: 0.0019
# Epoch 129/330
# 3/3 [==============================] - 0s 30ms/step - loss: 4.8505e-04 - val_loss: 0.0019
# Epoch 130/330
# 3/3 [==============================] - 0s 30ms/step - loss: 4.8452e-04 - val_loss: 0.0019
# Epoch 131/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.8399e-04 - val_loss: 0.0019
# Epoch 132/330
# 3/3 [==============================] - 0s 29ms/step - loss: 4.8347e-04 - val_loss: 0.0019
# Epoch 133/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.8294e-04 - val_loss: 0.0019
# Epoch 134/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.8243e-04 - val_loss: 0.0019
# Epoch 135/330
# 3/3 [==============================] - 0s 25ms/step - loss: 4.8191e-04 - val_loss: 0.0019
# Epoch 136/330
# 3/3 [==============================] - 0s 26ms/step - loss: 4.8141e-04 - val_loss: 0.0019
# Epoch 137/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.8090e-04 - val_loss: 0.0020
# Epoch 138/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.8041e-04 - val_loss: 0.0020
# Epoch 139/330
# 3/3 [==============================] - 0s 29ms/step - loss: 4.7992e-04 - val_loss: 0.0020
# Epoch 140/330
# 3/3 [==============================] - 0s 29ms/step - loss: 4.7944e-04 - val_loss: 0.0020
# Epoch 141/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.7897e-04 - val_loss: 0.0020
# Epoch 142/330
# 3/3 [==============================] - 0s 26ms/step - loss: 4.7851e-04 - val_loss: 0.0020
# Epoch 143/330
# 3/3 [==============================] - 0s 29ms/step - loss: 4.7806e-04 - val_loss: 0.0020
# Epoch 144/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.7762e-04 - val_loss: 0.0020
# Epoch 145/330
# 3/3 [==============================] - 0s 26ms/step - loss: 4.7719e-04 - val_loss: 0.0020
# Epoch 146/330
# 3/3 [==============================] - 0s 30ms/step - loss: 4.7677e-04 - val_loss: 0.0021
# Epoch 147/330
# 3/3 [==============================] - 0s 34ms/step - loss: 4.7637e-04 - val_loss: 0.0021
# Epoch 148/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.7598e-04 - val_loss: 0.0021
# Epoch 149/330
# 3/3 [==============================] - 0s 26ms/step - loss: 4.7561e-04 - val_loss: 0.0021
# Epoch 150/330
# 3/3 [==============================] - 0s 26ms/step - loss: 4.7525e-04 - val_loss: 0.0021
# Epoch 151/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.7491e-04 - val_loss: 0.0021
# Epoch 152/330
# 3/3 [==============================] - 0s 29ms/step - loss: 4.7458e-04 - val_loss: 0.0021
# Epoch 153/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.7427e-04 - val_loss: 0.0021
# Epoch 154/330
# 3/3 [==============================] - 0s 26ms/step - loss: 4.7397e-04 - val_loss: 0.0022
# Epoch 155/330
# 3/3 [==============================] - 0s 26ms/step - loss: 4.7369e-04 - val_loss: 0.0022
# Epoch 156/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.7342e-04 - val_loss: 0.0022
# Epoch 157/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.7317e-04 - val_loss: 0.0022
# Epoch 158/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.7294e-04 - val_loss: 0.0022
# Epoch 159/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.7272e-04 - val_loss: 0.0022
# Epoch 160/330
# 3/3 [==============================] - 0s 36ms/step - loss: 4.7251e-04 - val_loss: 0.0022
# Epoch 161/330
# 3/3 [==============================] - 0s 37ms/step - loss: 4.7232e-04 - val_loss: 0.0022
# Epoch 162/330
# 3/3 [==============================] - 0s 32ms/step - loss: 4.7214e-04 - val_loss: 0.0023
# Epoch 163/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.7197e-04 - val_loss: 0.0023
# Epoch 164/330
# 3/3 [==============================] - 0s 36ms/step - loss: 4.7181e-04 - val_loss: 0.0023
# Epoch 165/330
# 3/3 [==============================] - 0s 35ms/step - loss: 4.7167e-04 - val_loss: 0.0023
# Epoch 166/330
# 3/3 [==============================] - 0s 36ms/step - loss: 4.7153e-04 - val_loss: 0.0023
# Epoch 167/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.7140e-04 - val_loss: 0.0023
# Epoch 168/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.7128e-04 - val_loss: 0.0023
# Epoch 169/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.7117e-04 - val_loss: 0.0024
# Epoch 170/330
# 3/3 [==============================] - 0s 37ms/step - loss: 4.7106e-04 - val_loss: 0.0024
# Epoch 171/330
# 3/3 [==============================] - 0s 36ms/step - loss: 4.7095e-04 - val_loss: 0.0024
# Epoch 172/330
# 3/3 [==============================] - 0s 32ms/step - loss: 4.7085e-04 - val_loss: 0.0024
# Epoch 173/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.7075e-04 - val_loss: 0.0024
# Epoch 174/330
# 3/3 [==============================] - 0s 35ms/step - loss: 4.7064e-04 - val_loss: 0.0024
# Epoch 175/330
# 3/3 [==============================] - 0s 29ms/step - loss: 4.7054e-04 - val_loss: 0.0024
# Epoch 176/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.7044e-04 - val_loss: 0.0024
# Epoch 177/330
# 3/3 [==============================] - 0s 30ms/step - loss: 4.7034e-04 - val_loss: 0.0024
# Epoch 178/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.7023e-04 - val_loss: 0.0025
# Epoch 179/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.7012e-04 - val_loss: 0.0025
# Epoch 180/330
# 3/3 [==============================] - 0s 30ms/step - loss: 4.7001e-04 - val_loss: 0.0025
# Epoch 181/330
# 3/3 [==============================] - 0s 29ms/step - loss: 4.6989e-04 - val_loss: 0.0025
# Epoch 182/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.6976e-04 - val_loss: 0.0025
# Epoch 183/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.6963e-04 - val_loss: 0.0025
# Epoch 184/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.6950e-04 - val_loss: 0.0025
# Epoch 185/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.6936e-04 - val_loss: 0.0025
# Epoch 186/330
# 3/3 [==============================] - 0s 30ms/step - loss: 4.6921e-04 - val_loss: 0.0025
# Epoch 187/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.6906e-04 - val_loss: 0.0025
# Epoch 188/330
# 3/3 [==============================] - 0s 36ms/step - loss: 4.6890e-04 - val_loss: 0.0025
# Epoch 189/330
# 3/3 [==============================] - 0s 35ms/step - loss: 4.6874e-04 - val_loss: 0.0025
# Epoch 190/330
# 3/3 [==============================] - 0s 32ms/step - loss: 4.6856e-04 - val_loss: 0.0026
# Epoch 191/330
# 3/3 [==============================] - 0s 32ms/step - loss: 4.6839e-04 - val_loss: 0.0026
# Epoch 192/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.6820e-04 - val_loss: 0.0026
# Epoch 193/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.6801e-04 - val_loss: 0.0026
# Epoch 194/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.6782e-04 - val_loss: 0.0026
# Epoch 195/330
# 3/3 [==============================] - 0s 37ms/step - loss: 4.6762e-04 - val_loss: 0.0026
# Epoch 196/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.6741e-04 - val_loss: 0.0026
# Epoch 197/330
# 3/3 [==============================] - 0s 30ms/step - loss: 4.6720e-04 - val_loss: 0.0026
# Epoch 198/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.6699e-04 - val_loss: 0.0026
# Epoch 199/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.6677e-04 - val_loss: 0.0026
# Epoch 200/330
# 3/3 [==============================] - 0s 35ms/step - loss: 4.6654e-04 - val_loss: 0.0026
# Epoch 201/330
# 3/3 [==============================] - 0s 36ms/step - loss: 4.6632e-04 - val_loss: 0.0026
# Epoch 202/330
# 3/3 [==============================] - 0s 32ms/step - loss: 4.6608e-04 - val_loss: 0.0026
# Epoch 203/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.6585e-04 - val_loss: 0.0026
# Epoch 204/330
# 3/3 [==============================] - 0s 32ms/step - loss: 4.6561e-04 - val_loss: 0.0026
# Epoch 205/330
# 3/3 [==============================] - 0s 36ms/step - loss: 4.6537e-04 - val_loss: 0.0026
# Epoch 206/330
# 3/3 [==============================] - 0s 37ms/step - loss: 4.6513e-04 - val_loss: 0.0026
# Epoch 207/330
# 3/3 [==============================] - 0s 32ms/step - loss: 4.6488e-04 - val_loss: 0.0026
# Epoch 208/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.6463e-04 - val_loss: 0.0026
# Epoch 209/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.6438e-04 - val_loss: 0.0027
# Epoch 210/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.6413e-04 - val_loss: 0.0027
# Epoch 211/330
# 3/3 [==============================] - 0s 34ms/step - loss: 4.6387e-04 - val_loss: 0.0027
# Epoch 212/330
# 3/3 [==============================] - 0s 32ms/step - loss: 4.6362e-04 - val_loss: 0.0027
# Epoch 213/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.6336e-04 - val_loss: 0.0027
# Epoch 214/330
# 3/3 [==============================] - 0s 36ms/step - loss: 4.6310e-04 - val_loss: 0.0027
# Epoch 215/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.6284e-04 - val_loss: 0.0027
# Epoch 216/330
# 3/3 [==============================] - 0s 32ms/step - loss: 4.6258e-04 - val_loss: 0.0027
# Epoch 217/330
# 3/3 [==============================] - 0s 34ms/step - loss: 4.6232e-04 - val_loss: 0.0027
# Epoch 218/330
# 3/3 [==============================] - 0s 32ms/step - loss: 4.6206e-04 - val_loss: 0.0027
# Epoch 219/330
# 3/3 [==============================] - 0s 35ms/step - loss: 4.6180e-04 - val_loss: 0.0027
# Epoch 220/330
# 3/3 [==============================] - 0s 36ms/step - loss: 4.6153e-04 - val_loss: 0.0027
# Epoch 221/330
# 3/3 [==============================] - 0s 35ms/step - loss: 4.6127e-04 - val_loss: 0.0027
# Epoch 222/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.6100e-04 - val_loss: 0.0027
# Epoch 223/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.6074e-04 - val_loss: 0.0027
# Epoch 224/330
# 3/3 [==============================] - 0s 32ms/step - loss: 4.6048e-04 - val_loss: 0.0027
# Epoch 225/330
# 3/3 [==============================] - 0s 30ms/step - loss: 4.6021e-04 - val_loss: 0.0027
# Epoch 226/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.5994e-04 - val_loss: 0.0027
# Epoch 227/330
# 3/3 [==============================] - 0s 36ms/step - loss: 4.5968e-04 - val_loss: 0.0027
# Epoch 228/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.5941e-04 - val_loss: 0.0027
# Epoch 229/330
# 3/3 [==============================] - 0s 36ms/step - loss: 4.5915e-04 - val_loss: 0.0027
# Epoch 230/330
# 3/3 [==============================] - 0s 36ms/step - loss: 4.5888e-04 - val_loss: 0.0027
# Epoch 231/330
# 3/3 [==============================] - 0s 34ms/step - loss: 4.5862e-04 - val_loss: 0.0027
# Epoch 232/330
# 3/3 [==============================] - 0s 34ms/step - loss: 4.5835e-04 - val_loss: 0.0027
# Epoch 233/330
# 3/3 [==============================] - 0s 34ms/step - loss: 4.5808e-04 - val_loss: 0.0027
# Epoch 234/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.5782e-04 - val_loss: 0.0027
# Epoch 235/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.5755e-04 - val_loss: 0.0027
# Epoch 236/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.5729e-04 - val_loss: 0.0027
# Epoch 237/330
# 3/3 [==============================] - 0s 34ms/step - loss: 4.5702e-04 - val_loss: 0.0027
# Epoch 238/330
# 3/3 [==============================] - 0s 35ms/step - loss: 4.5676e-04 - val_loss: 0.0027
# Epoch 239/330
# 3/3 [==============================] - 0s 30ms/step - loss: 4.5649e-04 - val_loss: 0.0028
# Epoch 240/330
# 3/3 [==============================] - 0s 29ms/step - loss: 4.5623e-04 - val_loss: 0.0028
# Epoch 241/330
# 3/3 [==============================] - 0s 26ms/step - loss: 4.5596e-04 - val_loss: 0.0028
# Epoch 242/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.5570e-04 - val_loss: 0.0028
# Epoch 243/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.5543e-04 - val_loss: 0.0028
# Epoch 244/330
# 3/3 [==============================] - 0s 30ms/step - loss: 4.5517e-04 - val_loss: 0.0028
# Epoch 245/330
# 3/3 [==============================] - 0s 30ms/step - loss: 4.5490e-04 - val_loss: 0.0028
# Epoch 246/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.5464e-04 - val_loss: 0.0028
# Epoch 247/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.5438e-04 - val_loss: 0.0028
# Epoch 248/330
# 3/3 [==============================] - 0s 26ms/step - loss: 4.5411e-04 - val_loss: 0.0028
# Epoch 249/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.5385e-04 - val_loss: 0.0028
# Epoch 250/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.5358e-04 - val_loss: 0.0028
# Epoch 251/330
# 3/3 [==============================] - 0s 25ms/step - loss: 4.5332e-04 - val_loss: 0.0028
# Epoch 252/330
# 3/3 [==============================] - 0s 26ms/step - loss: 4.5306e-04 - val_loss: 0.0028
# Epoch 253/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.5279e-04 - val_loss: 0.0028
# Epoch 254/330
# 3/3 [==============================] - 0s 25ms/step - loss: 4.5253e-04 - val_loss: 0.0028
# Epoch 255/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.5226e-04 - val_loss: 0.0028
# Epoch 256/330
# 3/3 [==============================] - 0s 29ms/step - loss: 4.5200e-04 - val_loss: 0.0028
# Epoch 257/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.5174e-04 - val_loss: 0.0028
# Epoch 258/330
# 3/3 [==============================] - 0s 30ms/step - loss: 4.5147e-04 - val_loss: 0.0028
# Epoch 259/330
# 3/3 [==============================] - 0s 37ms/step - loss: 4.5121e-04 - val_loss: 0.0028
# Epoch 260/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.5095e-04 - val_loss: 0.0028
# Epoch 261/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.5068e-04 - val_loss: 0.0028
# Epoch 262/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.5042e-04 - val_loss: 0.0028
# Epoch 263/330
# 3/3 [==============================] - 0s 29ms/step - loss: 4.5015e-04 - val_loss: 0.0028
# Epoch 264/330
# 3/3 [==============================] - 0s 26ms/step - loss: 4.4989e-04 - val_loss: 0.0028
# Epoch 265/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.4963e-04 - val_loss: 0.0028
# Epoch 266/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.4936e-04 - val_loss: 0.0028
# Epoch 267/330
# 3/3 [==============================] - 0s 29ms/step - loss: 4.4910e-04 - val_loss: 0.0028
# Epoch 268/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.4883e-04 - val_loss: 0.0028
# Epoch 269/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.4857e-04 - val_loss: 0.0028
# Epoch 270/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.4830e-04 - val_loss: 0.0028
# Epoch 271/330
# 3/3 [==============================] - 0s 25ms/step - loss: 4.4804e-04 - val_loss: 0.0028
# Epoch 272/330
# 3/3 [==============================] - 0s 26ms/step - loss: 4.4777e-04 - val_loss: 0.0028
# Epoch 273/330
# 3/3 [==============================] - 0s 30ms/step - loss: 4.4751e-04 - val_loss: 0.0028
# Epoch 274/330
# 3/3 [==============================] - 0s 26ms/step - loss: 4.4724e-04 - val_loss: 0.0028
# Epoch 275/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.4697e-04 - val_loss: 0.0028
# Epoch 276/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.4671e-04 - val_loss: 0.0028
# Epoch 277/330
# 3/3 [==============================] - 0s 26ms/step - loss: 4.4644e-04 - val_loss: 0.0029
# Epoch 278/330
# 3/3 [==============================] - 0s 25ms/step - loss: 4.4618e-04 - val_loss: 0.0029
# Epoch 279/330
# 3/3 [==============================] - 0s 26ms/step - loss: 4.4591e-04 - val_loss: 0.0029
# Epoch 280/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.4564e-04 - val_loss: 0.0029
# Epoch 281/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.4537e-04 - val_loss: 0.0029
# Epoch 282/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.4510e-04 - val_loss: 0.0029
# Epoch 283/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.4484e-04 - val_loss: 0.0029
# Epoch 284/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.4457e-04 - val_loss: 0.0029
# Epoch 285/330
# 3/3 [==============================] - 0s 36ms/step - loss: 4.4430e-04 - val_loss: 0.0029
# Epoch 286/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.4403e-04 - val_loss: 0.0029
# Epoch 287/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.4376e-04 - val_loss: 0.0029
# Epoch 288/330
# 3/3 [==============================] - 0s 37ms/step - loss: 4.4349e-04 - val_loss: 0.0029
# Epoch 289/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.4322e-04 - val_loss: 0.0029
# Epoch 290/330
# 3/3 [==============================] - 0s 41ms/step - loss: 4.4295e-04 - val_loss: 0.0029
# Epoch 291/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.4267e-04 - val_loss: 0.0029
# Epoch 292/330
# 3/3 [==============================] - 0s 35ms/step - loss: 4.4240e-04 - val_loss: 0.0029
# Epoch 293/330
# 3/3 [==============================] - 0s 34ms/step - loss: 4.4213e-04 - val_loss: 0.0029
# Epoch 294/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.4186e-04 - val_loss: 0.0029
# Epoch 295/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.4158e-04 - val_loss: 0.0029
# Epoch 296/330
# 3/3 [==============================] - 0s 35ms/step - loss: 4.4131e-04 - val_loss: 0.0029
# Epoch 297/330
# 3/3 [==============================] - 0s 36ms/step - loss: 4.4103e-04 - val_loss: 0.0029
# Epoch 298/330
# 3/3 [==============================] - 0s 35ms/step - loss: 4.4076e-04 - val_loss: 0.0029
# Epoch 299/330
# 3/3 [==============================] - 0s 35ms/step - loss: 4.4048e-04 - val_loss: 0.0029
# Epoch 300/330
# 3/3 [==============================] - 0s 35ms/step - loss: 4.4021e-04 - val_loss: 0.0029
# Epoch 301/330
# 3/3 [==============================] - 0s 32ms/step - loss: 4.3993e-04 - val_loss: 0.0029
# Epoch 302/330
# 3/3 [==============================] - 0s 35ms/step - loss: 4.3965e-04 - val_loss: 0.0029
# Epoch 303/330
# 3/3 [==============================] - 0s 34ms/step - loss: 4.3937e-04 - val_loss: 0.0029
# Epoch 304/330
# 3/3 [==============================] - 0s 36ms/step - loss: 4.3910e-04 - val_loss: 0.0029
# Epoch 305/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.3882e-04 - val_loss: 0.0029
# Epoch 306/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.3854e-04 - val_loss: 0.0029
# Epoch 307/330
# 3/3 [==============================] - 0s 36ms/step - loss: 4.3826e-04 - val_loss: 0.0029
# Epoch 308/330
# 3/3 [==============================] - 0s 37ms/step - loss: 4.3797e-04 - val_loss: 0.0029
# Epoch 309/330
# 3/3 [==============================] - 0s 38ms/step - loss: 4.3769e-04 - val_loss: 0.0029
# Epoch 310/330
# 3/3 [==============================] - 0s 38ms/step - loss: 4.3741e-04 - val_loss: 0.0029
# Epoch 311/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.3713e-04 - val_loss: 0.0029
# Epoch 312/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.3684e-04 - val_loss: 0.0029
# Epoch 313/330
# 3/3 [==============================] - 0s 32ms/step - loss: 4.3656e-04 - val_loss: 0.0029
# Epoch 314/330
# 3/3 [==============================] - 0s 29ms/step - loss: 4.3627e-04 - val_loss: 0.0029
# Epoch 315/330
# 3/3 [==============================] - 0s 29ms/step - loss: 4.3599e-04 - val_loss: 0.0029
# Epoch 316/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.3570e-04 - val_loss: 0.0029
# Epoch 317/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.3541e-04 - val_loss: 0.0029
# Epoch 318/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.3512e-04 - val_loss: 0.0029
# Epoch 319/330
# 3/3 [==============================] - 0s 28ms/step - loss: 4.3484e-04 - val_loss: 0.0029
# Epoch 320/330
# 3/3 [==============================] - 0s 27ms/step - loss: 4.3455e-04 - val_loss: 0.0029
# Epoch 321/330
# 3/3 [==============================] - 0s 31ms/step - loss: 4.3426e-04 - val_loss: 0.0029
# Epoch 322/330
# 3/3 [==============================] - 0s 26ms/step - loss: 4.3396e-04 - val_loss: 0.0029
# Epoch 323/330
# 3/3 [==============================] - 0s 30ms/step - loss: 4.3367e-04 - val_loss: 0.0029
# Epoch 324/330
# 3/3 [==============================] - 0s 26ms/step - loss: 4.3338e-04 - val_loss: 0.0029
# Epoch 325/330
# 3/3 [==============================] - 0s 34ms/step - loss: 4.3309e-04 - val_loss: 0.0029
# Epoch 326/330
# 3/3 [==============================] - 0s 35ms/step - loss: 4.3279e-04 - val_loss: 0.0029
# Epoch 327/330
# 3/3 [==============================] - 0s 33ms/step - loss: 4.3250e-04 - val_loss: 0.0029
# Epoch 328/330
# 3/3 [==============================] - 0s 37ms/step - loss: 4.3220e-04 - val_loss: 0.0029
# Epoch 329/330
# 3/3 [==============================] - 0s 35ms/step - loss: 4.3190e-04 - val_loss: 0.0029
# Epoch 330/330
# 3/3 [==============================] - 0s 32ms/step - loss: 4.3161e-04 - val_loss: 0.0029

# %%
#Visual plot to check if the error is reducing
pyplot.plot(LSTMModel_fit.history['loss'], label='train')
pyplot.plot(LSTMModel_fit.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
error_Training_LSTM = mean_squared_error(Y_train_LSTM, LSTMModel.predict(X_train_LSTM))
predicted = LSTMModel.predict(X_test_LSTM)
error_Test_LSTM = mean_squared_error(Y_test,predicted)

# %% [markdown]
# #### Append to previous results

# %%
test_results.append(error_Test_ARIMA)
test_results.append(error_Test_LSTM)

train_results.append(error_Training_ARIMA)
train_results.append(error_Training_LSTM)

names.append("ARIMA")
names.append("LSTM")

# %% [markdown]
# ## Overall Comparison of all the algorithms ( including Time Series Algorithms)

# %%
# compare algorithms
fig = pyplot.figure()

ind = np.arange(len(names))  # the x locations for the groups
width = 0.35  # the width of the bars

fig.suptitle('Comparing the performance of various algorthims on the Train and Test Dataset')
ax = fig.add_subplot(111)
pyplot.bar(ind - width/2, train_results,  width=width, label='Train Error')
pyplot.bar(ind + width/2, test_results, width=width, label='Test Error')
fig.set_size_inches(15,8)
pyplot.legend()
ax.set_xticks(ind)
ax.set_xticklabels(names)
pyplot.ylabel('Mean Square Error')
pyplot.show()

# %% [markdown]
# Looking at the chart above, we find time series based ARIMA model comparable to
# the linear supervised-regression models such as Linear Regression (LR), Lasso Regres‐
# sion (LASSO) and Elastic Net (EN). This can primarily be due to the strong linear
# relationship as discussed before. The LSTM model performs decently, however,
# ARIMA model outperforms the LSTM model in the test set. Hence, we select the
# ARIMA model for the model tuning.

# %% [markdown]
# <a id='5'></a>
# # 6. Model Tuning and Grid Search

# %% [markdown]
# As shown in the chart above the ARIMA model is one of the best mode, so we perform the model tuning of the ARIMA model. The default order of ARIMA model is [1,0,0]. We perform a grid search with different combination p,d and q in the ARIMA model's order.

# %%
#Grid Search for ARIMA Model
#Change p,d and q and check for the best result

# evaluate an ARIMA model for a given order (p,d,q)
#Assuming that the train and Test Data is already defined before
def evaluate_arima_model(arima_order):
    #predicted = list()
    modelARIMA=ARIMA(endog=Y_train,exog=X_train_ARIMA,order=arima_order)
    model_fit = modelARIMA.fit()
    error = mean_squared_error(Y_train, model_fit.fittedvalues)
    return error

# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(p_values, d_values, q_values):
    best_score, best_cfg = float("inf"), None
    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p,d,q)
                try:
                    mse = evaluate_arima_model(order)
                    if mse < best_score:
                        best_score, best_cfg = mse, order
                    print('ARIMA%s MSE=%.7f' % (order,mse))
                except:
                    continue
    print('Best ARIMA%s MSE=%.7f' % (best_cfg, best_score))

# evaluate parameters
p_values = range(0,5)
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) MSE=0.0006429
# ARIMA(0, 0, 1) MSE=0.0006394
# ARIMA(0, 0, 2) MSE=0.0006354
# ARIMA(1, 0, 0) MSE=0.0006403
# ARIMA(2, 0, 0) MSE=0.0006380
# ARIMA(2, 0, 1) MSE=0.0006064
# ARIMA(3, 0, 0) MSE=0.0006313
# ARIMA(3, 0, 1) MSE=0.0006063
# ARIMA(3, 0, 2) MSE=0.0006057
# ARIMA(4, 0, 0) MSE=0.0006299
# ARIMA(4, 0, 1) MSE=0.0006063
# ARIMA(4, 0, 2) MSE=0.0006062
# Best ARIMA(3, 0, 2) MSE=0.0006057

# %% [markdown]
# <a id='6'></a>
# # 7. Finalise the Model

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1. Results on the Test Dataset

# %%
# prepare model
modelARIMA_tuned=ARIMA(endog=Y_train,exog=X_train_ARIMA,order=[3,0,2])
model_fit_tuned = modelARIMA_tuned.fit()

# %%
# estimate accuracy on validation set
predicted_tuned = model_fit_tuned.predict(start = tr_len -1 ,end = to_len -1, exog = X_test_ARIMA)[1:]
print(mean_squared_error(Y_test,predicted_tuned))
# Out:
# 0.001572736648129615

# %%
error_Training_tuned_ARIMA = mean_squared_error(Y_train, model_fit_tuned.fittedvalues)
predicted_tuned = model_fit_tuned.predict(start = tr_len -1 ,end = to_len -1, exog = X_test_ARIMA)[1:]
error_Test_tuned_ARIMA = mean_squared_error(Y_test,predicted_tuned)
error_Test_tuned_ARIMA
# Out:
# 0.001572736648129615

# %%
test_results.append(error_Test_tuned_ARIMA)

train_results.append(error_Training_tuned_ARIMA)

names.append("TUNED")

# %%
# compare algorithms
fig = pyplot.figure()

ind = np.arange(len(names))  # the x locations for the groups
width = 0.35  # the width of the bars

fig.suptitle('Comparing the performance of various algorthims on the Train and Test Dataset')
ax = fig.add_subplot(111)
pyplot.bar(ind - width/2, train_results,  width=width, label='Train Error')
pyplot.bar(ind + width/2, test_results, width=width, label='Test Error')
fig.set_size_inches(15,8)
pyplot.legend()
ax.set_xticks(ind)
ax.set_xticklabels(names)
pyplot.ylabel('Mean Square Error')
pyplot.show()

# %% [markdown]
# After tuning the model and picking the best ARIMA model or the order 2,0 and 1 we select this model and can it can be used for the modeling purpose.

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2. Save Model for Later Use

# %%
# Save Model Using Pickle
from pickle import dump
from pickle import load

# save the model to disk
filename = 'finalized_model.sav'
dump(model_fit_tuned, open(filename, 'wb'))

# %%
#Use the following code to produce the comparison of actual vs. predicted
predicted_tuned.index = Y_test.index
pyplot.plot(np.exp(Y_test).cumprod(), 'r') # plotting t, a separately
pyplot.plot(np.exp(predicted_tuned).cumprod(), 'b')
pyplot.rcParams["figure.figsize"] = (8,5)
pyplot.show()

# %% [markdown]
# ### Summary

# %% [markdown]
# We can conclude that simple models - linear regression, regularized regression (i.e.
# Lasso and elastic net) - along with the time series model such as ARIMA are promis‐
# ing modelling approaches for asset price prediction problem. These models can
# enable financial practitioners to model time dependencies with a very flexible
# approach. The overall approach presented in this case study may help us encounter
# overfitting and underfitting which are some of the key challenges in the prediction
# problem in finance.
# We should also note that we can use better set of indicators, such as P/E ratio, trading
# volume, technical indicators or news data, which might lead to better results. We will
# demonstrate this in some of the case studies in the book.
# Overall, we created a supervised-regression and time series modelling framework
# which allows us to perform asset class prediction using historical data to generate
# results and analyze risk and profitability before risking any actual capital.
