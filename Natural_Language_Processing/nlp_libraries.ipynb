# %% [markdown]
# # NLTK

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# Download necessary NLTK data files
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# Example sentence
sentence = "NLTK is a leading platform for building Python programs to work with human language data."

# Tokenization
tokens = word_tokenize(sentence)
print("Tokens:", tokens)

# Stemming
stemmer = PorterStemmer()
stems = [stemmer.stem(token) for token in tokens]
print("Stems:", stems)

# Lemmatization
lemmatizer = WordNetLemmatizer()
lemmas = [lemmatizer.lemmatize(token) for token in tokens]
print("Lemmas:", lemmas)
# Out:
# Tokens: ['NLTK', 'is', 'a', 'leading', 'platform', 'for', 'building', 'Python', 'programs', 'to', 'work', 'with', 'human', 'language', 'data', '.']
# Stems: ['nltk', 'is', 'a', 'lead', 'platform', 'for', 'build', 'python', 'program', 'to', 'work', 'with', 'human', 'languag', 'data', '.']
# Lemmas: ['NLTK', 'is', 'a', 'leading', 'platform', 'for', 'building', 'Python', 'program', 'to', 'work', 'with', 'human', 'language', 'data', '.']

# %% [markdown]
# # SpaCy

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm

# %%
import spacy

# Load the SpaCy model
nlp = spacy.load("en_core_web_sm")

# Example sentence
sentence = "SpaCy is an amazing NLP library. It supports named entity recognition, dependency parsing, and more."

# Process the sentence with SpaCy
doc = nlp(sentence)

# Tokenization
tokens = [token.text for token in doc]
print("Tokens:", tokens)

# Part-of-Speech Tagging
pos_tags = [(token.text, token.pos_) for token in doc]
print("POS Tags:", pos_tags)

# Named Entity Recognition
entities = [(entity.text, entity.label_) for entity in doc.ents]
print("Entities:", entities)
# Out:
# Tokens: ['SpaCy', 'is', 'an', 'amazing', 'NLP', 'library', '.', 'It', 'supports', 'named', 'entity', 'recognition', ',', 'dependency', 'parsing', ',', 'and', 'more', '.']
# POS Tags: [('SpaCy', 'PROPN'), ('is', 'AUX'), ('an', 'DET'), ('amazing', 'ADJ'), ('NLP', 'PROPN'), ('library', 'NOUN'), ('.', 'PUNCT'), ('It', 'PRON'), ('supports', 'VERB'), ('named', 'VERB'), ('entity', 'NOUN'), ('recognition', 'NOUN'), (',', 'PUNCT'), ('dependency', 'NOUN'), ('parsing', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('more', 'ADJ'), ('.', 'PUNCT')]
# Entities: [('NLP', 'ORG')]

# %% [markdown]
# ![POS tagging.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# # TextBlob

# %%
# !pip install textblob
# !python -m textblob.download_corpora

# %%
from textblob import TextBlob

# Example text
text = "NLP is very important for ML engineers"

# Create a TextBlob object
blob = TextBlob(text)

# Sentiment analysis
sentiment = blob.sentiment
print("Sentiment:", sentiment)

# Part-of-speech tagging
pos_tags = blob.tags
print("Part-of-Speech Tags:", pos_tags)

# Noun phrase extraction
noun_phrases = blob.noun_phrases
print("Noun Phrases:", noun_phrases)
# Out:
# Sentiment: Sentiment(polarity=0.52, subjectivity=1.0)
# Part-of-Speech Tags: [('NLP', 'NNP'), ('is', 'VBZ'), ('very', 'RB'), ('important', 'JJ'), ('for', 'IN'), ('ML', 'NNP'), ('engineers', 'NNS')]
# Noun Phrases: ['nlp', 'ml']

# %% [markdown]
# # Transformers

# %%
# !pip install transformers
# !pip install --upgrade transformers
# !pip install --upgrade huggingface_hub

# %%
from transformers import pipeline

# Load the pre-trained sentiment-analysis pipeline
classifier = pipeline("sentiment-analysis")

# Example text
text = "Transformers is an amazing library for NLP tasks. It's incredibly powerful and easy to use."

# Perform sentiment analysis
result = classifier(text)

# Print results
print("Sentiment Analysis Result with default pipeline:")
print(result)

classifier = pipeline(model="finiteautomata/bertweet-base-sentiment-analysis")
result = classifier(text)
print("Sentiment Analysis Result with specific model:")
print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Sentiment Analysis Result with default pipeline:
# [{'label': 'POSITIVE', 'score': 0.9998286962509155}]
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Sentiment Analysis Result with specific model:
# [{'label': 'POS', 'score': 0.9927806258201599}]
